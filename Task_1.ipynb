# %% [markdown]
# <a href="https://colab.research.google.com/github/manimegalai1507/Skillcraft-technology-task-/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt


ages = [18, 19, 20, 21, 22, 23, 24, 25, 30, 35, 40, 45, 50, 55, 60]


plt.hist(ages)
plt.title("Age Distribution of Population")
plt.xlabel("Age")
plt.ylabel("Frequency")


plt.show()
